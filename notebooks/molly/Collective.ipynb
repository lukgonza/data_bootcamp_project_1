# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import csv
from operator import itemgetter

# %%
#print(os.getcwd())

data = pd.read_csv(r"C:\Users\mvesk\RiceBootcamp_project1\data_bootcamp_project_1\data\imdb-data-from-2006-to-2016\IMDB-Movie-Data.csv")
#data = pd.read_csv('..\data\IMDB-Movie-Data.csv')

revised_data =pd.read_csv(r"C:\Users\mvesk\RiceBootcamp_project1\data_bootcamp_project_1\data\imdb_revised_data.csv")
#revised_data = pd.read_csv('..\data\imdb_revised_data.csv')
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
revised_data.head()
# Out:
#    Unnamed: 0  Rank                    Title                     Genre  \
# 0           0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1           1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2           2     3                    Split           Horror,Thriller
# 3           3     4                     Sing   Animation,Comedy,Family
# 4           4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
print(len(data))
print(len(revised_data))
# Out:
# 1000
# 1000

# %%
print(data.columns)
print(revised_data.columns)
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
# Index(['Unnamed: 0', 'Rank', 'Title', 'Genre', 'Description', 'Director',
#        'Actors', 'Year', 'Runtime (Minutes)', 'Rating', 'Votes',
#        'Revenue (Millions)', 'Metascore', 'Genre1', 'Genre2', 'Genre3',
#        'Actor1', 'Actor2', 'Actor3', 'Actor4'],
#       dtype='object')

# %%
del revised_data['Unnamed: 0']

# %%
revised_data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
# Rank                  1000 non-null int64
# Title                 1000 non-null object
# Genre                 1000 non-null object
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Runtime (Minutes)     1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.8+ KB

# %%
revised_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
# Rank                  1000 non-null int64
# Title                 1000 non-null object
# Genre                 1000 non-null object
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Runtime (Minutes)     1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# Genre1                1000 non-null object
# Genre2                895 non-null object
# Genre3                660 non-null object
# Actor1                1000 non-null object
# Actor2                1000 non-null object
# Actor3                1000 non-null object
# Actor4                999 non-null object
# ...

# %%
# convert in category to count and use these columns
revised_data.Title = revised_data.Title.astype('category')
revised_data.Genre = revised_data.Genre.astype('category')
revised_data.Year = revised_data.Year.astype('int64')

# %%
revised_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
# Rank                  1000 non-null int64
# Title                 1000 non-null category
# Genre                 1000 non-null category
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Runtime (Minutes)     1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# Genre1                1000 non-null object
# Genre2                895 non-null object
# Genre3                660 non-null object
# Actor1                1000 non-null object
# Actor2                1000 non-null object
# Actor3                1000 non-null object
# Actor4                999 non-null object
# ...

# %%
#https://github.com/nicolaschen1/DataScienceMovies/blob/master/DataScienceMovies.ipynb

# %%
revised_data.Genre.cat.categories
# Out:
# Index(['Action', 'Action,Adventure', 'Action,Adventure,Biography',
#        'Action,Adventure,Comedy', 'Action,Adventure,Crime',
#        'Action,Adventure,Drama', 'Action,Adventure,Family',
#        'Action,Adventure,Fantasy', 'Action,Adventure,Horror',
#        'Action,Adventure,Mystery',
#        ...
#        'Mystery,Romance,Thriller', 'Mystery,Sci-Fi,Thriller',
#        'Mystery,Thriller', 'Mystery,Thriller,Western', 'Romance,Sci-Fi',
#        'Romance,Sci-Fi,Thriller', 'Sci-Fi', 'Sci-Fi,Thriller', 'Thriller',
#        'Thriller,War'],
#       dtype='object', length=207)

# %%
dict_list=[]
dict_list=revised_data.columns
dict_list
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Genre1', 'Genre2', 'Genre3', 'Actor1', 'Actor2', 'Actor3',
#        'Actor4'],
#       dtype='object')

# %%
dict_list2=[]
for line in revised_data:
    dict_list2.append(line)
    
dict_list2
# Out:
# ['Unnamed: 0',
#  'Rank',
#  'Title',
#  'Genre',
#  'Description',
#  'Director',
#  'Actors',
#  'Year',
#  'Runtime (Minutes)',
#  'Rating',
#  'Votes',
#  'Revenue (Millions)',
#  'Metascore',
#  'Genre1',
#  'Genre2',
#  'Genre3',
#  'Actor1',
#  'Actor2',
#  'Actor3',
#  'Actor4']

# %%
revised_data =pd.read_csv(r"C:\Users\mvesk\RiceBootcamp_project1\data_bootcamp_project_1\data\imdb_revised_data.csv")

def CSVbuilding():
    #prompt the user for a file to import
    filter = "CSV file (*.csv)|*.csv|*.txt|All Files (*.*)|*.*||"
    revised_data =pd.read_csv(r"C:\Users\mvesk\RiceBootcamp_project1\data_bootcamp_project_1\data\imdb_revised_data.csv")

    with open(revised_data) as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            print(row)

# %%
#Creating a dictionary with the csv
#list of dictionaries
dicts=revised_data.to_dict('records')
dicts
# Out:
# [{'Rank': 1,
#   'Title': 'Guardians of the Galaxy',
#   'Genre': 'Action,Adventure,Sci-Fi',
#   'Description': 'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#   'Director': 'James Gunn',
#   'Actors': 'Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana',
#   'Year': 2014,
#   'Runtime (Minutes)': 121,
#   'Rating': 8.1,
#   'Votes': 757074,
#   'Revenue (Millions)': 333.13,
#   'Metascore': 76.0,
#   'Genre1': 'Action',
#   'Genre2': 'Adventure',
#   'Genre3': 'Sci-Fi',
#   'Actor1': 'Chris Pratt',
#   'Actor2': ' Vin Diesel',
#   'Actor3': ' Bradley Cooper',
#   'Actor4': ' Zoe Saldana'},
#  {'Rank': 2,
#   'Title': 'Prometheus',
#   'Genre': 'Adventure,Mystery,Sci-Fi',
#   'Description': 'Following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.',
#   'Director': 'Ridley Scott',
# ...

# %%
#Creating a dictionary with the csv
#list of dictionaries
dicts=revised_data.to_dict('records')
dicts
# Out:
# The lowest rank movie is Nine Lives, who is 1000 rank.

# %%
genre_rev = {"Revenue":[],"Genre":[], "Count":[]}

Genre_play = {}


for Genre_name in revised_data['Genre1'].dropna():
    if Genre_name not in Genre_play.keys():
        Genre_play[Genre_name] = 1        
    else:
        Genre_play[Genre_name] = Genre_play[Genre_name] + 1
        
for Genre_name in revised_data['Genre2'].dropna():
    if Genre_name not in Genre_play.keys():
        Genre_play[Genre_name] = 1
    else:
        Genre_play[Genre_name] = Genre_play[Genre_name] + 1
Genre_play
# Out:
# {'Action': 303,
#  'Adventure': 250,
#  'Horror': 95,
#  'Animation': 49,
#  'Comedy': 237,
#  'Biography': 79,
#  'Drama': 433,
#  'Crime': 129,
#  'Romance': 71,
#  'Mystery': 62,
#  'Thriller': 62,
#  'Sci-Fi': 31,
#  'Fantasy': 39,
#  'Family': 27,
#  'History': 8,
#  'Music': 8,
#  'Western': 2,
#  'War': 4,
#  'Musical': 1,
#  'Sport': 5}

# %%
dictionary = plt.figure()

plt.bar(range(len(Genre_play)), Genre_play.values(), alpha=0.8, align='center')
plt.xticks(range(len(Genre_play)), Genre_play.keys(), rotation="vertical")
#plt.savefig('genrevscount.png')
# Out:
# ([<matplotlib.axis.XTick at 0x1b7c93e8828>],
#  <a list of 1 Text xticklabel objects>)

# %%
genre_rev = {"Revenue":[],"Genre":[], "Count":[]}
Genre_play = {}

for Genre_name in revised_data['Genre1'].dropna():
    if Genre_name not in Genre_play.keys():
        Genre_play[Genre_name] = 1 
        genre_rev['Count'] = 1
        genre_rev['Genre'] =Genre_name
        genre_rev['Revenue']=revised_data['Revenue (Millions)']+genre_rev['Revenue']
    else:
        Genre_play[Genre_name] = Genre_play[Genre_name] + 1
        
for Genre_name in revised_data['Genre2'].dropna():
    if Genre_name not in Genre_play.keys():
        Genre_play[Genre_name] = 1
    else:
        Genre_play[Genre_name] = Genre_play[Genre_name] + 1
Genre_play
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-afac8c777e91> in <module>()
#       7         genre_rev['Count'] = 1
#       8         genre_rev['Genre'] =Genre_name
# ----> 9         genre_rev['Revenue']=revised_data['Revenue (Millions)']+genre_rev['Revenue']
#      10     else:
#      11         Genre_play[Genre_name] = Genre_play[Genre_name] + 1
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1031         try:
#    1032             with np.errstate(all='ignore'):
# ...

# %%
dictionary = plt.figure()

plt.bar(range(len(Genre_play)), Genre_play.values(), alpha=0.8, align='center')
plt.xticks(range(len(Genre_play)), Genre_play.keys(), rotation="vertical")

# %%
revised_data.groupby('Title')['Rating'].value_counts()
# Out:
# Title                              Rating
# (500) Days of Summer               7.7       1
# 10 Cloverfield Lane                7.2       1
# 10 Years                           6.1       1
# 12 Years a Slave                   8.1       1
# 127 Hours                          7.6       1
# 13 Hours                           7.3       1
# 1408                               6.8       1
# 17 Again                           6.4       1
# 2012                               5.8       1
# 20th Century Women                 7.4       1
# 21                                 6.8       1
# 21 Jump Street                     7.2       1
# 22 Jump Street                     7.1       1
# 2307: Winter's Dream               4.0       1
# 28 Weeks Later                     7.0       1
# 3 Days to Kill                     6.2       1
# 3 Idiots                           8.4       1
# 300                                7.7       1
# 300: Rise of an Empire             6.2       1
# ...

# %%
#revised_data.groupby('Title')['Rating'].value_counts().unstack().fillna('NaN')
# Out:
# Rating                             1.9  2.7  3.2  3.5  3.7  3.9  4.0  4.1  \
# Title
# (500) Days of Summer               NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10 Cloverfield Lane                NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10 Years                           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 12 Years a Slave                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 127 Hours                          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13 Hours                           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1408                               NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17 Again                           NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2012                               NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20th Century Women                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 21                                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 21 Jump Street                     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
movie_genre_index = revised_data['Genre1'].str.contains('Action')
movie_genre = revised_data[movie_genre_index]
movie_genre
# Out:
#      Rank                                        Title  \
# 0       1                      Guardians of the Galaxy
# 4       5                                Suicide Squad
# 5       6                               The Great Wall
# 8       9                           The Lost City of Z
# 12     13                                    Rogue One
# 14     15                                     Colossal
# 17     18                                 Jason Bourne
# 24     25                 Independence Day: Resurgence
# 26     27                      Bahubali: The Beginning
# 29     30                             Assassin's Creed
# 32     33                            X-Men: Apocalypse
# 33     34                                     Deadpool
# 34     35             Resident Evil: The Final Chapter
# 35     36                   Captain America: Civil War
# 37     38                               Doctor Strange
# 38     39                        The Magnificent Seven
# ...

# %%
data[['Rank']].count()
data.Rank.count()
# Out:
# 1000

# %%
data.Votes.sum()
# Out:
# 169808255

# %%
data.Rating.min()
# Out:
# 1.9

# %%
data.Rating.max()
# Out:
# 9.0

# %%
data.Rating.mean()
# Out:
# 6.723200000000003

# %%
data.Rating.median()
# Out:
# 6.8

# %%
data.groupby('Rating').mean()
# Out:
#               Rank         Year  Runtime (Minutes)         Votes  \
# Rating
# 1.9     830.000000  2008.000000          87.000000  7.720700e+04
# 2.7     457.500000  2012.500000          79.000000  3.000400e+04
# 3.2     648.000000  2016.000000         133.000000  1.730000e+02
# 3.5     930.000000  2015.500000          93.500000  7.060000e+02
# 3.7     160.000000  2016.000000         107.500000  1.685500e+03
# 3.9     388.666667  2016.000000          93.000000  1.895667e+03
# 4.0     617.000000  2016.000000         101.000000  2.770000e+02
# 4.1      64.000000  2015.000000         125.000000  2.444740e+05
# 4.2     710.500000  2013.000000         102.500000  6.676900e+04
# 4.3     704.000000  2013.500000         107.000000  6.874150e+04
# 4.4     937.000000  2009.000000          92.000000  6.065500e+04
# 4.5     772.000000  2016.000000          95.000000  2.043000e+03
# 4.6     747.600000  2015.800000          86.600000  9.665400e+03
# ...

# %%
bins = [0,100,200,300,400,500,600,700]
group_names = ["0 to 99", "100 to 199", "200 to 299", "300 to 399","400 to 499", "500 to 599", "600+"]

revised_data["Rev Summary"] = pd.cut(revised_data['Revenue (Millions)'], bins, labels=group_names)
revised_data
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
group_df = revised_data.groupby("Rev Summary")
group_df.mean()
# Out:
#                    Rank         Year  Runtime (Minutes)    Rating  \
# Rev Summary
# 0 to 99      541.797101  2012.787440         111.930757  6.708535
# 100 to 199   402.686667  2011.640000         119.800000  6.933333
# 200 to 299   369.473684  2011.403509         121.192982  7.294737
# 300 to 399   311.653846  2012.230769         126.384615  7.111538
# 400 to 499   276.454545  2012.272727         133.909091  7.481818
# 500 to 599    34.000000  2012.000000         142.500000  8.450000
# 600+          81.500000  2013.500000         133.500000  7.550000
#
#                     Votes  Revenue (Millions)  Metascore
# Rev Summary
# 0 to 99      1.232539e+05           32.749114  57.939086
# 100 to 199   2.978823e+05          139.206133  61.619048
# 200 to 299   4.064968e+05          240.098421  65.982143
# 300 to 399   4.165257e+05          335.083846  64.769231
# 400 to 499   5.533493e+05          425.814545  68.727273
# 500 to 599   1.057517e+06          532.745000  73.500000
# ...

# %%
#group_df['Votes'].count()
# Out:
# Rev Summary
# 0 to 99       621
# 100 to 199    150
# 200 to 299     57
# 300 to 399     26
# 400 to 499     11
# 500 to 599      2
# 600+            2
# Name: Votes, dtype: int64

# %%
group_df[["Runtime (Minutes)", "Rating", "Votes"]].mean()
# Out:
#              Runtime (Minutes)    Rating         Votes
# Rev Summary
# 0 to 99             111.930757  6.708535  1.232539e+05
# 100 to 199          119.800000  6.933333  2.978823e+05
# 200 to 299          121.192982  7.294737  4.064968e+05
# 300 to 399          126.384615  7.111538  4.165257e+05
# 400 to 499          133.909091  7.481818  5.533493e+05
# 500 to 599          142.500000  8.450000  1.057517e+06
# 600+                133.500000  7.550000  7.503785e+05

# %%
plt.figure()
df=data['Revenue _Millions']
df.plot.hist(alpha=10)
plt.savefig('HistagramRevenue.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-be045a708965> in <module>()
#       1 plt.figure()
#       2 df=data['Revenue (Millions)']
# ----> 3 df.plot.hist(alpha=10)
#       4 plt.savefig('HistagramRevenue.png')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist(self, bins, **kwds)
#    2831         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2832         """
# ...

# %%
average_votes = revised_data["Votes"].mean()
average_votes
# Out:
# 169808.255

# %%
# Create a group based on the values in the 'year' column
year_group = data.groupby('Year')

# Count how many times each year appears in our group
count_year = year_group['Year'].count()

count_year
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Year, dtype: int64

# %%
# Create a bar chart based off of the group series from before
count_chart = count_year.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("year")
count_chart.set_ylabel("Number of Movies")


plt.show()
plt.tight_layout()
plt.savefig('MovieCountvsYear.png')

# %%
# Create a group based on the values in the 'rev summary' column
money_group = revised_data.groupby("Rev Summary")

# Count how many times each year appears in our group
count_money = money_group["Rev Summary"].count()

count_money
# Out:
# Rev Summary
# 0 to 99       621
# 100 to 199    150
# 200 to 299     57
# 300 to 399     26
# 400 to 499     11
# 500 to 599      2
# 600+            2
# Name: Rev Summary, dtype: int64

# %%
# Create a bar chart based off of the group series from before
count_chart = count_money.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("reveunue catagories")
count_chart.set_ylabel("count")


plt.show()
plt.tight_layout()

# %%
#group by year
# Create a group based on the values in the 'rev summary' column
money_group = revised_data.groupby("Rev_Summary")

# Count how many times each "" appears in our group
count_money = money_group["Rev_Summary"].count()

count_money

# Create a bar chart based off of the group series from before
count_chart = count_money.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("reveunue catagories")
count_chart.set_ylabel("count")


plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-10b42d16c454> in <module>()
#       1 #group by year
#       2 # Create a group based on the values in the 'rev summary' column
# ----> 3 money_group = revised_data.groupby("Rev_Summary")
#       4
#       5 # Count how many times each "" appears in our group
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
# ...

# %%
df3 = pd.DataFrame(revised_data, columns= ['Genre','Year','Rank','Votes', 'Revenue (Millions)','Genre1','Genre2','Genre3'])
df3
# Out:
#                           Genre  Year  Rank   Votes  Revenue (Millions)  \
# 0       Action,Adventure,Sci-Fi  2014     1  757074              333.13
# 1      Adventure,Mystery,Sci-Fi  2012     2  485820              126.46
# 2               Horror,Thriller  2016     3  157606              138.12
# 3       Animation,Comedy,Family  2016     4   60545              270.32
# 4      Action,Adventure,Fantasy  2016     5  393727              325.02
# 5      Action,Adventure,Fantasy  2016     6   56036               45.13
# 6            Comedy,Drama,Music  2016     7  258682              151.06
# 7                        Comedy  2016     8    2490                 NaN
# 8    Action,Adventure,Biography  2016     9    7188                8.01
# 9       Adventure,Drama,Romance  2016    10  192177              100.01
# 10     Adventure,Family,Fantasy  2016    11  232072              234.02
# 11      Biography,Drama,History  2016    12   93103              169.27
# ...

# %%
df4 = pd.DataFrame(revised_data) #['Genre','Year', 'Revenue (Millions)','Genre1','Genre2','Genre3'])
df4
# Out:
#      Unnamed: 0  Rank                                    Title  \
# 0             0     1                  Guardians of the Galaxy
# 1             1     2                               Prometheus
# 2             2     3                                    Split
# 3             3     4                                     Sing
# 4             4     5                            Suicide Squad
# 5             5     6                           The Great Wall
# 6             6     7                               La La Land
# 7             7     8                                 Mindhorn
# 8             8     9                       The Lost City of Z
# 9             9    10                               Passengers
# 10           10    11  Fantastic Beasts and Where to Find Them
# 11           11    12                           Hidden Figures
# 12           12    13                                Rogue One
# 13           13    14                                    Moana
# ...

# %%
# create histogram for numeric data 
df3.describe()
df3.hist()
# show plot
plt.show()

# %%
df3.describe()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# Genre                 1000 non-null category
# Year                  1000 non-null int64
# Rank                  1000 non-null int64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Genre1                1000 non-null object
# Genre2                895 non-null object
# Genre3                660 non-null object
# dtypes: category(1), float64(1), int64(3), object(3)
# memory usage: 68.3+ KB

# %%
# create histogram for numeric data 
df4.hist()
# show plot
plt.show()

# %%
df5 = pd.DataFrame(revised_data, columns= ['Year','Votes'])
df5
# create histogram for numeric data 
df5.hist()
# show plot
plt.show()

df5.plot.bar() 
  
# plot between 2 attributes 
plt.bar(df5['Year'], df5['Votes']) 
plt.xlabel("Year") 
plt.ylabel("Votes") 
plt.show()

# %%
dict_list3=[]
for line in revised_data:
    dict_list3.append(line)
    
dict_list3
# Out:
# ['Rank',
#  'Title',
#  'Genre',
#  'Description',
#  'Director',
#  'Actors',
#  'Year',
#  'Runtime (Minutes)',
#  'Rating',
#  'Votes',
#  'Revenue (Millions)',
#  'Metascore',
#  'Genre1',
#  'Genre2',
#  'Genre3',
#  'Actor1',
#  'Actor2',
#  'Actor3',
#  'Actor4',
#  'Rev Summary']

# %%
dataframe1 = pd.data({"Genre,":["Genre1","Genre2""Genre3"]})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-79481f99c0f4> in <module>()
# ----> 1 dataframe1 = pd.data({"Genre,":["Genre1","Genre2""Genre3"]})
#
# AttributeError: module 'pandas' has no attribute 'data'

# %%
#rev_counts = data["Revenue (Millions)"].value_counts()
#rev_counts
#top_ten = rev_counts[0:10]
#top_ten

data.sort_values(["Revenue (Millions)"], axis=0, 
                 ascending=True, inplace=True) 
data
# Out:
#      Rank                                          Title  \
# 231   232                               A Kind of Murder
# 321   322                                       Lovesong
# 677   678                                    Love, Rosie
# 27     28                                     Dead Awake
# 68     69                                      Wakefield
# 961   962                                Into the Forest
# 490   491                                     Stake Land
# 927   928                               The Sea of Trees
# 736   737                       The Blackcoat's Daughter
# 661   662                                 The First Time
# 659   660                                   The Daughter
# 265   266                                    Knock Knock
# 435   436                                          Filth
# 648   649                                Sleeping Beauty
# 618   619                                      Mr. Right
# ...

# %%
revised_data.sort_values(["Genre1", "Revenue (Millions)"], axis=0, 
                 ascending=[False,False], inplace=True) 
revised_data
# Out:
#      Rank                                             Title  \
# 729   730                                         The Guest
# 160   161                                              Mine
# 282   283                                       Death Proof
# 289   290                                              Iris
# 444   445                                      The Thinning
# 746   747                                Only for One Night
# 848   849                                       Mean Dreams
# 911   912     I Am the Pretty Thing That Lives in the House
# 933   934                                            Detour
# 942   943                                        Transpecos
# 512   513                                     The Happening
# 616   617                              2307: Winter's Dream
# 183   184                                           Realive
# 706   707                             The Adjustment Bureau
# 112   113                                     The Bad Batch
# ...

# %%
print(revised_data.columns)
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Genre1', 'Genre2', 'Genre3', 'Actor1', 'Actor2', 'Actor3',
#        'Actor4', 'Rev Summary'],
#       dtype='object')

# %%
dataMovies_genre1 = revised_data.loc[
                        ((revised_data.Genre == 'Action') | (revised_data.Genre == 'Adventure') 
                       (revised_data.Genre == 'Animation') | (revised_data.Genre == 'Biography') | \
                       (revised_data.Genre == 'Comedy') | (revised_data.Genre == 'Crime') | \
                        (revised_data.Genre == 'Documentary') | (revised_data.Genre == 'Drama') | \
                       (revised_data.Genre == 'Family') | (revised_data.Genre == 'Fantasy') | \
                       (revised_data.Genre == 'Horror') | (revised_data.Genre == 'Music')| \
                        (revised_data.Genre == 'Mystery') | (revised_data.Genre == 'Romance') | \
                       (revised_data.Genre == 'Sci') | (revised_data.Genre == 'Thriller'))]

#(revised_data.Genre == 'War') | (revised_data.Genre == 'Western')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-23b89ea75323> in <module>()
#       7                        (revised_data.Genre == 'Horror') | (revised_data.Genre == 'Music')| \
#       8                         (revised_data.Genre == 'Mystery') | (revised_data.Genre == 'Romance') | \
# ----> 9                        (revised_data.Genre == 'Sci') | (revised_data.Genre == 'Thriller'))]
#      10
#      11 #(revised_data.Genre == 'War') | (revised_data.Genre == 'Western')
#
# TypeError: 'Series' object is not callable

# %%
dataMovies_genre1
# Out:
#      Rank                         Title      Genre  \
# 255   256                  The Hangover     Comedy
# 722   723                     Grown Ups     Comedy
# 719   720                     Neighbors     Comedy
# 394   395                   Grown Ups 2     Comedy
# 148   149                      Superbad     Comedy
# 28     29                      Bad Moms     Comedy
# 397   398               Couples Retreat     Comedy
# 360   361                 Step Brothers     Comedy
# 790   791                       Sisters     Comedy
# 983   984                 Let's Be Cops     Comedy
# 740   741                      The Boss     Comedy
# 30     31                      Why Him?     Comedy
# 834   835                  The Dictator     Comedy
# 639   640              American Reunion     Comedy
# 292   293  Neighbors 2: Sorority Rising     Comedy
# 115   116        Office Christmas Party     Comedy
# 994   995                     Project X     Comedy
# ...

# %%
print (sorted(dicts, key=itemgetter('Genre1')))
# Out:
# [{'Rank': 1, 'Title': 'Guardians of the Galaxy', 'Genre': 'Action,Adventure,Sci-Fi', 'Description': 'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.', 'Director': 'James Gunn', 'Actors': 'Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana', 'Year': 2014, 'Runtime (Minutes)': 121, 'Rating': 8.1, 'Votes': 757074, 'Revenue (Millions)': 333.13, 'Metascore': 76.0, 'Genre1': 'Action', 'Genre2': 'Adventure', 'Genre3': 'Sci-Fi', 'Actor1': 'Chris Pratt', 'Actor2': ' Vin Diesel', 'Actor3': ' Bradley Cooper', 'Actor4': ' Zoe Saldana'}, {'Rank': 5, 'Title': 'Suicide Squad', 'Genre': 'Action,Adventure,Fantasy', 'Description': 'A secret government agency recruits some of the most dangerous incarcerated super-villains to form a defensive task force. Their first mission: save the world from the apocalypse.', 'Director': 'David Ayer', 'Actors': 'Will Smith, Jared Leto, Margot Robbie, Viola Davis', 'Year': 2016, 'Runtime
# ...

# %%
#print (sorted(dicts, key=itemgetter('Genre1')))     
print(dicts.get("Genre1"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-e8011f8d96b5> in <module>()
#       1 #print (sorted(dicts, key=itemgetter('Genre1')))
# ----> 2 print(dicts.get("Genre1"))
#
# AttributeError: 'list' object has no attribute 'get'

# %%
print(dicts.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-f05794ed5f88> in <module>()
# ----> 1 print(dicts.keys())
#
# AttributeError: 'list' object has no attribute 'keys'

# %% [markdown]
# # DATASET 3
# gyms = ["Crunch", "Planet Fitness", "NY Sports Club", "Rickie's Gym"]
# members = [49, 92, 84, 53]
# colors = ["yellowgreen", "red", "lightcoral", "lightskyblue"]
# explode = (0, 0.05, 0, 0)
#
# plt.title("NYC Gym Popularity")
# plt.pie(members, explode=explode, labels=gyms, colors=colors,
#         autopct="%1.1f%%", shadow=True, startangle=90)
# plt.axis("equal")
# plt.show()

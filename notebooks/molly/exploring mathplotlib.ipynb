# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from operator import itemgetter
from scipy.stats import ttest_ind, ttest_ind_from_stats
from scipy.special import stdtr
import seaborn as sns
import matplotlib.pyplot as plt
from math import isnan
#import plotly.tools as tls

# %matplotlib notebook
#http://localhost:8888/notebooks/RICEHOU201811DATA2/class-tth/05-Matplotlib/5.2%20-%20Matplotlib%20Advanced%20Customization/Activities/04-Ins_GroupPlots/Solved/plotting_groups.ipynb

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import our data into pandas from CSV
#used_string = '../Resources/used_cars.csv'
data = pd.read_csv(r"C:\Users\mvesk\RiceBootcamp_project1\data_bootcamp_project_1\data\imdb_revised.csv")
#data = pd.read_csv('..\data\imdb_revised.csv')
data.head()
# Out:
#    Rank                    Title     Genre1     Genre2   Genre3  \
# 0     1  Guardians of the Galaxy     Action  Adventure   Sci-Fi
# 1     2               Prometheus  Adventure    Mystery   Sci-Fi
# 2     3                    Split     Horror   Thriller      NaN
# 3     4                     Sing  Animation     Comedy   Family
# 4     5            Suicide Squad     Action  Adventure  Fantasy
#
#                Director              Actors1                Actors2  \
# 0            James Gunn          Chris Pratt             Vin Diesel
# 1          Ridley Scott         Noomi Rapace   Logan Marshall-Green
# 2    M. Night Shyamalan         James McAvoy        Anya Taylor-Joy
# 3  Christophe Lourdelet  Matthew McConaughey      Reese Witherspoon
# 4            David Ayer           Will Smith             Jared Leto
#
#                 Actors3              Actors4  Year  Runtime (Minutes)  Rating  \
# 0        Bradley Cooper          Zoe Saldana  2014                121     8.1
# 1    Michael Fassbender      Charlize Theron  2012                124     7.0
# 2   Haley Lu Richardson         Jessica Sula  2016                117     7.3
# 3       Seth MacFarlane   Scarlett Johansson  2016                108     7.2
# 4         Margot Robbie          Viola Davis  2016                123     6.2
#
#     Votes  Revenue (Millions)  Metascore
# 0  757074              333.13       76.0
# 1  485820              126.46       65.0
# 2  157606              138.12       62.0
# 3   60545              270.32       59.0
# 4  393727              325.02       40.0

# %%
# Create a group based on the values in the 'year' column
year_group = data.groupby('Year')

# Count how many times each year appears in our group
count_year = year_group['Year'].count()

count_year
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Year, dtype: int64

# %%
# Create a bar chart based off of the group series from before
count_chart = count_year.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("year")
count_chart.set_ylabel("Number of Movies")


plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Create a group based on the values in the 'year' column
money_group = data.groupby('Revenue (Millions)')

# Count how many times each year appears in our group
count_money = money_group['Revenue (Millions)'].count()

count_money
money=data('Revenue (Millions)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-6f857970c6fd> in <module>()
#       6
#       7 count_money
# ----> 8 money=data('Revenue (Millions)')
#
# TypeError: 'DataFrame' object is not callable

# %%
# Create a bar chart based off of the group series from before
count_chart2 = count_money.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart2.set_xlabel("Genre")
count_chart2.set_ylabel("revenue in millions")


plt.show()
plt.tight_layout()

# %%
Genre_play = {}

for Genre_name in data['Genre1'].dropna():
    if Genre_name not in Genre_play.keys():
        Genre_play[Genre_name] = 1
    else:
        Genre_play[Genre_name] = Genre_play[Genre_name] + 1
        
for Genre_name in data['Genre2'].dropna():
    if Genre_name not in Genre_play.keys():
        Genre_play[Genre_name] = 1
    else:
        Genre_play[Genre_name] = Genre_play[Genre_name] + 1
Genre_play
# Out:
# {'Action': 303,
#  'Adventure': 250,
#  'Horror': 95,
#  'Animation': 49,
#  'Comedy': 237,
#  'Biography': 79,
#  'Drama': 433,
#  'Crime': 129,
#  'Romance': 71,
#  'Mystery': 62,
#  'Thriller': 62,
#  'Sci-Fi': 31,
#  'Fantasy': 39,
#  'Family': 27,
#  'History': 8,
#  'Music': 8,
#  'Western': 2,
#  'War': 4,
#  'Musical': 1,
#  'Sport': 5}

# %%
dictionary = plt.figure()

plt.bar(range(len(Genre_play)), Genre_play.values(), alpha=0.8, align='center')
plt.xticks(range(len(Genre_play)), Genre_play.keys(), rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x1f3562aa630>,
#   <matplotlib.axis.XTick at 0x1f3562a6f28>,
#   <matplotlib.axis.XTick at 0x1f3562a6c88>,
#   <matplotlib.axis.XTick at 0x1f355bd0668>,
#   <matplotlib.axis.XTick at 0x1f355bd0b38>,
#   <matplotlib.axis.XTick at 0x1f355bd0d68>,
#   <matplotlib.axis.XTick at 0x1f355bd8518>,
#   <matplotlib.axis.XTick at 0x1f355bd89e8>,
#   <matplotlib.axis.XTick at 0x1f355bd8eb8>,
#   <matplotlib.axis.XTick at 0x1f355be13c8>,
#   <matplotlib.axis.XTick at 0x1f355be1898>,
#   <matplotlib.axis.XTick at 0x1f355be1d68>,
#   <matplotlib.axis.XTick at 0x1f355be1978>,
#   <matplotlib.axis.XTick at 0x1f355bd8860>,
#   <matplotlib.axis.XTick at 0x1f355bd04e0>,
#   <matplotlib.axis.XTick at 0x1f355be8518>,
#   <matplotlib.axis.XTick at 0x1f355be89e8>,
#   <matplotlib.axis.XTick at 0x1f355be8eb8>,
#   <matplotlib.axis.XTick at 0x1f355bf43c8>,
#   <matplotlib.axis.XTick at 0x1f355bf4898>],
#  <a list of 20 Text xticklabel objects>)

# %%
dictionary = plt.figure()

plt.bar(range(len(Genre_play)), Genre_play.values(), alpha=0.8, align='center')
plt.xticks(range(len(Genre_play)), Genre_play.keys(), rotation="vertical")
Genre_play.values()
# Out:
# <img src="data:image/png;base64,..." width="640">
# dict_values([303, 250, 95, 49, 237, 79, 433, 129, 71, 62, 62, 31, 39, 27, 8, 8, 2, 4, 1, 5])
